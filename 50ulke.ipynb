# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
lk=pd.read_csv("50lke.csv")

# %%
lk.head(10)
# Out:
#    SIRALAMA         ÜLKELER  MİLLİ GELİR     2023  BÜYÜME  KİŞİ BAŞINA  \
# 0         1   United States     20412.87  24537.0    2.27      62152.0
# 1         2           China     14092.51  21574.0    6.86      10088.0
# 2         3           Japan      5167.05   5962.0    1.71      40849.0
# 3         4         Germany      4211.64   5272.0    2.51      50842.0
# 4         5  United Kingdom      2936.29   3477.0    1.79      44177.0
# 5         6          France      2925.10   3586.0    1.85      44934.0
# 6         7           India      2848.23   4663.0    6.74       2135.0
# 7         8           Italy      2181.97   2554.0    1.47      35914.0
# 8         9          Brazil      2138.92   2717.0    0.98      10224.0
# 9        10          Canada      1798.51   2434.0    3.00      48466.0
#
#    SIRALAMA.2           KITA
# 0           9  North America
# 1          72           Asia
# 2          25           Asia
# 3          17         Europe
# 4          23         Europe
# ...

# %%
lk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SIRALAMA     50 non-null     int64
#  1   ÜLKELER      50 non-null     object
#  2   MİLLİ GELİR  50 non-null     float64
#  3   2023         50 non-null     float64
#  4   BÜYÜME       50 non-null     float64
#  5   KİŞİ BAŞINA  50 non-null     float64
#  6   SIRALAMA.2   50 non-null     int64
#  7   KITA         50 non-null     object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 3.2+ KB

# %%
lk.describe()
# Out:
#        SIRALAMA   MİLLİ GELİR         2023     BÜYÜME   KİŞİ BAŞINA  \
# count  50.00000     50.000000     50.00000  50.000000     50.000000
# mean   25.50000   1646.348200   2149.22000   3.320400  27696.000000
# std    14.57738   3448.554429   4518.18979   2.053468  25094.131496
# min     1.00000    231.570000    301.80000  -0.740000   1615.000000
# 25%    13.25000    353.440000    466.90000   1.795000   6402.000000
# 50%    25.50000    522.985000    672.70000   2.880000  14565.500000
# 75%    37.75000   1504.895000   1937.25000   4.287500  48738.250000
# max    50.00000  20412.870000  24537.00000   7.810000  86835.000000
#
#        SIRALAMA.2
# count   50.000000
# mean    55.040000
# std     45.200217
# min      2.000000
# 25%     18.250000
# 50%     39.500000
# 75%     81.500000
# max    151.000000

# %%
lk.pop("2023")
# Out:
# 0     24537.0
# 1     21574.0
# 2      5962.0
# 3      5272.0
# 4      3477.0
# 5      3586.0
# 6      4663.0
# 7      2554.0
# 8      2717.0
# 9      2434.0
# 10     1974.0
# 11     2155.0
# 12     1875.0
# 13     1958.0
# 14     1586.0
# 15     1549.0
# 16     1168.0
# 17     1224.0
# 18      866.0
# 19      929.3
# 20      831.7
# 21      793.2
# 22      659.6
# 23      745.0
# 24      685.8
# 25      649.9
# 26      595.4
# 27      520.6
# 28      472.3
# 29      515.4
# 30      873.9
# 31      505.6
# 32      482.1
# 33      455.8
# 34      465.4
# 35      568.0
# 36      489.8
# 37      437.8
# 38      523.0
# 39      435.0
# 40      471.4
# 41      356.8
# 42      444.2
# 43      359.8
# 44      367.6
# 45      358.2
# 46      301.8
# 47      350.6
# 48      373.8
# 49      311.2
# Name: 2023, dtype: float64

# %%
lk.isnull().sum()
# Out:
# SIRALAMA       0
# ÜLKELER        0
# MİLLİ GELİR    0
# BÜYÜME         0
# KİŞİ BAŞINA    0
# SIRALAMA.2     0
# KITA           0
# dtype: int64

# %%
lk=pd.read_csv("50lke.csv")
lk.dropna(how="any",inplace=True)
lk
# Out:
#     SIRALAMA                   ÜLKELER  MİLLİ GELİR     2023  BÜYÜME  \
# 0          1             United States     20412.87  24537.0    2.27
# 1          2                     China     14092.51  21574.0    6.86
# 2          3                     Japan      5167.05   5962.0    1.71
# 3          4                   Germany      4211.64   5272.0    2.51
# 4          5            United Kingdom      2936.29   3477.0    1.79
# 5          6                    France      2925.10   3586.0    1.85
# 6          7                     India      2848.23   4663.0    6.74
# 7          8                     Italy      2181.97   2554.0    1.47
# 8          9                    Brazil      2138.92   2717.0    0.98
# 9         10                    Canada      1798.51   2434.0    3.00
# 10        11                    Russia      1719.90   1974.0    1.55
# 11        12                     Korea      1693.25   2155.0    3.09
# 12        13                     Spain      1506.44   1875.0    3.05
# ...

# %%
sns.set(style="dark",palette="muted",font_scale=1)
sns.distplot(lk["KİŞİ BAŞINA"],bins=20,kde=False,color="y")

plt.tight_layout()
# Out:
# E:\Soker\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set(style="darkgrid",palette="muted",font_scale=1)
sns.distplot(lk["2023"],hist=False,rug=True,color="r")
plt.tight_layout()
# Out:
# E:\Soker\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# E:\Soker\lib\site-packages\seaborn\distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
sns.jointplot(lk["KİŞİ BAŞINA"], lk["MİLLİ GELİR"], data=lk)
# Out:
# E:\Soker\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(lk,palette="#95a5a6")

# %%
sns.boxplot(x="KITA",y="KİŞİ BAŞINA",data=lk,width=1)
plt.tight_layout()

# %%
sns.barplot(x="KITA",y="KİŞİ BAŞINA",data=lk,palette="RdBu_r")
# Out:
# <AxesSubplot:xlabel='KITA', ylabel='KİŞİ BAŞINA'>
